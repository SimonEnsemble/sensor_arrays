# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
sns.set(color_codes=True)

# %%
henrys = pd.read_csv("../data/Expt_Henry_Coeffs_v2.csv") # Change this to load in different data
henry_coeff = pd.DataFrame(henrys, columns=
                           ["CO2_henry coefficient [mmol/(g-bar)]",
                            "SO2_henry coefficient [mmol/(g-bar)]"])
henry_coeff.columns = ["CO2", "SO2"]
henry_coeff = henry_coeff.dropna() # Need to drop NaN values in order for the scatter plot to be able to pick it up
#henrys
henry_coeff
# Out:
#            CO2          SO2
# 0     2.440927    11.692121
# 1     4.607513   171.432416
# 2     1.418831    34.797254
# 3     1.370301    97.240663
# 4     2.206897    40.402008
# 5     3.275732   153.600000
# 6     7.965262   483.863591
# 7     4.657709   405.417914
# 8    16.173841  4108.772727
# 9   998.247377   367.978149
# 10  111.993821   469.905660
# 11    2.158665    19.169554
# 12    5.170580     4.364834

# %%
sns.pairplot(henry_coeff)

# %%
fig = plt.figure(figsize=(10,8))
plt.scatter(henry_coeff["CO2"], henry_coeff["SO2"])
plt.xlabel("CO2 Henry Coefficient [mmol/(g-bar)]")
plt.ylabel("SO2 Henry Coefficient [mmol/(g-bar)]")
plt.plot([0, 4500], [0, 4500], 'k--')
plt.xlim([-30, 1030])
plt.ylim([-100, 4300])
# Out:
# (-100, 4300)

# %%
fig = plt.figure(figsize=(10,8))
plt.scatter(henry_coeff["CO2"], henry_coeff["SO2"])
plt.xlabel("CO2 Henry Coefficient [mmol/(g-bar)]")
plt.ylabel("SO2 Henry Coefficient [mmol/(g-bar)]")
plt.plot([0, 4500], [0, 4500], 'k--')
plt.xlim([-10, 500])
plt.ylim([-10, 500])
# Out:
# (-10, 500)

# %%
fig = plt.figure(figsize=(10,8))
plt.scatter(henry_coeff["CO2"], henry_coeff["SO2"])
plt.xlabel("CO2 Henry Coefficient [mmol/(g-bar)]")
plt.ylabel("SO2 Henry Coefficient [mmol/(g-bar)]")
plt.plot([0, 4500], [0, 4500], 'k--')
plt.xlim([-1, 50])
plt.ylim([-1, 50])
# Out:
# (-1, 50)
